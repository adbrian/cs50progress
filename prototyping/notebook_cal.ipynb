# %%
import calendar
from datetime import datetime


class Pset:
    def __init__(self, name, date):
        self.name = name
        self.date = date

# %% [markdown]
# Given a list of dictionaries, with the latest submission being first, reverse the list so latest submission is last
# given a pset, get the date it was submitted
# given a date i want all the dates and days of the month as a list

# %% [markdown]
# create a calendar object, and verify our day starts on Sunday

# %%
cal = calendar.Calendar(firstweekday=calendar.SUNDAY)

list(cal.iterweekdays())
# Out:
# [6, 0, 1, 2, 3, 4, 5]

# %% [markdown]
# print all days of the month for a particular month

# %%
str_datetime = "2026-08-06 18:37:33Z"
str_date, str_time = str_datetime.split(" ")
print(f"date: {str_date}, {type(str_date)}")
print(f"time: {str_time}, {type(str_time)}")

dt_date = datetime.strptime(str_date, "%Y-%m-%d").date()
print(dt_date, type(dt_date))

# %% [markdown]
# i now have a date taken from the pset submission date
# lets construct a calendar using calendar module

# %%
print(cal.monthdayscalendar(dt_date.year, dt_date.month))
